# %% [markdown]
# # Lab 5 Group Project - Words light up your day

# %%
name = input("Please enter your name: ")
number = input("please rate your day, enter a number between 1-5 ")
number = int(number)
if number == 1:
    print(name + " Everything is gonna be ok")
elif number == 2:
    print( name + " Chin up and go")
elif number == 3:
    print( name + " Success is waiting ahead")
elif number == 4:
    print( name + " Great to hear! Keep up!")
elif number == 5:
    print( name + " Have a nice day YAY")
# Out:
# Please enter your name:  zzz
# please rate your day, enter a number between 1-5  2
# zzz Chin up and go
